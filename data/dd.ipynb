# %%
import pandas as pd

# %%
# Out:
#   PAR1ê0Ô+L µ,`Î)}B"6
# !äQB
# 2¦N
# BhÕZ
# S*g
# dìXs
# u®
#
# pÜ
# 2
# 
# §ô_¤
# ·¶¡°
# Èxã¼
# Ù:%É
# êüfÕ
# ú¾¨á
#
# êí
#
# ,-n~B=Ç¯
# Nñ
#
# _K3+
# o
# 0  u7
# Ï¶C
# øO
# ¢S:\
# ²|h
# Ã×½t
# ...
# 1  ã
# jlOï
# ,ðÒB²
# ­tV
# ...
# 2                                B[Þ
# kK #
# |
# 3
# 
# 4  O'
# Ï3
# ªÒ?
# »SL
# ÌVX
# Ý×d
# ...
