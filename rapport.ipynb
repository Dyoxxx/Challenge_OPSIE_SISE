# %%
import pandas as pd

# %%
#lire un fichier parquet 
data = pd.read_parquet('data/log_export.parquet')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 2
#       1 #lire un fichier parquet
# ----> 2 data = pd.read_parquet('data/log_export.parquet')
#
# File c:\Users\HP\Desktop\Master2\Challenge_OPSIE_SISE\.venv\Lib\site-packages\pandas\io\parquet.py:668, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     508 @set_module("pandas")
#     509 def read_parquet(
#     510     path: FilePath | ReadBuffer[bytes],
#    (...)    518     **kwargs,
#     519 ) -> DataFrame:
#     520     """
#     521     Load a parquet object from the file path, returning a DataFrame.
#     522
#    (...)    665     1    4    9
#     666     """
# --> 668     impl = get_engine(engine)
#     669     check_dtype_backend(dtype_backend)
#     671     return impl.read(
#     672         path,
# ...
